# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/Adm/Desktop/GoIT/stack-overflow-developer-survey-2023/survey_results_public.csv')

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
dfp = df.pivot_table(index='Industry', columns='RemoteWork', values='ConvertedCompYearly', aggfunc=np.mean)
display(dfp)
# Out:
# C:\Users\Adm\AppData\Local\Temp\ipykernel_16064\3047652468.py:1: FutureWarning: The provided callable <function mean at 0x00000255AC4B8A40> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   dfp = df.pivot_table(index='Industry', columns='RemoteWork', values='ConvertedCompYearly', aggfunc=np.mean)
# RemoteWork                                          Hybrid (some remote, some in-person)  \
# Industry
# Advertising Services                                                       111253.818182
# Financial Services                                                         141774.783699
# Healthcare                                                                  90572.272590
# Higher Education                                                            71734.458015
# Information Services, IT, Software Development,...                          97853.381956
# ...

# %%
df.RemoteWork
# Out:
# 0                                         NaN
# 1                                      Remote
# 2        Hybrid (some remote, some in-person)
# 3        Hybrid (some remote, some in-person)
# 4                                      Remote
#                          ...
# 89179                                  Remote
# 89180    Hybrid (some remote, some in-person)
# 89181                                     NaN
# 89182    Hybrid (some remote, some in-person)
# 89183    Hybrid (some remote, some in-person)
# Name: RemoteWork, Length: 89184, dtype: object

# %%
df['RemoteWork']
# Out:
# 0                                         NaN
# 1                                      Remote
# 2        Hybrid (some remote, some in-person)
# 3        Hybrid (some remote, some in-person)
# 4                                      Remote
#                          ...
# 89179                                  Remote
# 89180    Hybrid (some remote, some in-person)
# 89181                                     NaN
# 89182    Hybrid (some remote, some in-person)
# 89183    Hybrid (some remote, some in-person)
# Name: RemoteWork, Length: 89184, dtype: object

# %%
import seaborn as sns

# %%
sns.heatmap(data=dfp, cmap= 'crest_r')
# Out:
# <Axes: xlabel='RemoteWork', ylabel='Industry'>

# %%
dfp['Remote']
# Out:
# Industry
# Advertising Services                                                   118059.633540
# Financial Services                                                     113122.255074
# Healthcare                                                             120466.587486
# Higher Education                                                        86431.578947
# Information Services, IT, Software Development, or other Technology    103088.492116
# Insurance                                                              106415.603053
# Legal Services                                                          94236.813187
# Manufacturing, Transportation, or Supply Chain                          99358.951220
# Oil & Gas                                                               84348.084507
# Other                                                                  114206.274415
# Retail and Consumer Services                                           107105.090418
# ...

# %%
df.pivot_table(index='Industry', columns='RemoteWork', values='ConvertedCompYearly', aggfunc=np.round(np.mean, 2))

# %%
def round_mean(x):
    return np.round(np.mean(x), 2)

# %%
df.pivot_table(index='Industry', columns='RemoteWork', values='ConvertedCompYearly', aggfunc=lambda x: np.round(np.mean(x), 2))
# Out:
# RemoteWork                                          Hybrid (some remote, some in-person)  \
# Industry
# Advertising Services                                                           111253.82
# Financial Services                                                             141774.78
# Healthcare                                                                      90572.27
# Higher Education                                                                71734.46
# Information Services, IT, Software Development,...                              97853.38
# Insurance                                                                       79140.38
# Legal Services                                                                  89528.94
# Manufacturing, Transportation, or Supply Chain                                  95708.63
# Oil & Gas                                                                       96125.63
# ...

# %%
my_lambda = lambda x: np.round(np.mean(x), 2)
df.pivot_table(index='Industry', columns='RemoteWork', values='ConvertedCompYearly', aggfunc=my_lambda)
# Out:
# RemoteWork                                          Hybrid (some remote, some in-person)  \
# Industry
# Advertising Services                                                           111253.82
# Financial Services                                                             141774.78
# Healthcare                                                                      90572.27
# Higher Education                                                                71734.46
# Information Services, IT, Software Development,...                              97853.38
# Insurance                                                                       79140.38
# Legal Services                                                                  89528.94
# Manufacturing, Transportation, or Supply Chain                                  95708.63
# Oil & Gas                                                                       96125.63
# ...

# %%
dfp = df.pivot_table(index='Industry', columns='RemoteWork', values='ConvertedCompYearly', aggfunc=np.mean)
display(dfp)
# Out:
# C:\Users\Adm\AppData\Local\Temp\ipykernel_16064\3047652468.py:1: FutureWarning: The provided callable <function mean at 0x00000255AC4B8A40> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   dfp = df.pivot_table(index='Industry', columns='RemoteWork', values='ConvertedCompYearly', aggfunc=np.mean)
# RemoteWork                                          Hybrid (some remote, some in-person)  \
# Industry
# Advertising Services                                                       111253.818182
# Financial Services                                                         141774.783699
# Healthcare                                                                  90572.272590
# Higher Education                                                            71734.458015
# Information Services, IT, Software Development,...                          97853.381956
# ...

# %%
dfp['Remote'].apply(lambda x: np.round(np.mean(x), 2))
# Out:
# Industry
# Advertising Services                                                   118059.63
# Financial Services                                                     113122.26
# Healthcare                                                             120466.59
# Higher Education                                                        86431.58
# Information Services, IT, Software Development, or other Technology    103088.49
# Insurance                                                              106415.60
# Legal Services                                                          94236.81
# Manufacturing, Transportation, or Supply Chain                          99358.95
# Oil & Gas                                                               84348.08
# Other                                                                  114206.27
# Retail and Consumer Services                                           107105.09
# ...

# %%
dfp[['Hybrid (some remote, some in-person)','Remote']].apply(lambda x: np.round(np.mean(x), 2))
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)     95224.45
# Remote                                  102532.13
# dtype: float64

# %%
DataFrame.apply(func, axis=0, raw=False, result_type=None, args=(), **kwds)

# %%
dfp
# Out:
# RemoteWork                                          Hybrid (some remote, some in-person)  \
# Industry
# Advertising Services                                                       111253.818182
# Financial Services                                                         141774.783699
# Healthcare                                                                  90572.272590
# Higher Education                                                            71734.458015
# Information Services, IT, Software Development,...                          97853.381956
# Insurance                                                                   79140.384615
# Legal Services                                                              89528.939394
# Manufacturing, Transportation, or Supply Chain                              95708.629319
# Oil & Gas                                                                   96125.627660
# ...

# %%
DataFrame.map(func, na_action=None)

# %%
dfp.map(lambda x: x + 1000)
# Out:
# RemoteWork                                          Hybrid (some remote, some in-person)  \
# Industry
# Advertising Services                                                       112253.818182
# Financial Services                                                         142774.783699
# Healthcare                                                                  91572.272590
# Higher Education                                                            72734.458015
# Information Services, IT, Software Development,...                          98853.381956
# Insurance                                                                   80140.384615
# Legal Services                                                              90528.939394
# Manufacturing, Transportation, or Supply Chain                              96708.629319
# Oil & Gas                                                                   97125.627660
# ...

# %%
numpy.where(condition, x, y)

# %%
phones = pd.DataFrame({
    'Модель': ['iPhone X', 'iPhone 12', 'iPhone 14', 'Samsung Galaxy S23', 'Samsung Galaxy S22'],
    'Рік випуску': [2017, 2020, 2022, 2023, 2022],
    'Ціна': [12000, 16000, 29000, 40000, 26000]
})

print(phones)
# Out:
#                Модель  Рік випуску   Ціна
# 0            iPhone X         2017  12000
# 1           iPhone 12         2020  16000
# 2           iPhone 14         2022  29000
# 3  Samsung Galaxy S23         2023  40000
# 4  Samsung Galaxy S22         2022  26000

# %%
phones['Ціна'] = np.where(phones['Модель'] == 'iPhone 12', 800, phones['Ціна'])
phones
# Out:
#                Модель  Рік випуску   Ціна
# 0            iPhone X         2017  12000
# 1           iPhone 12         2020    800
# 2           iPhone 14         2022  29000
# 3  Samsung Galaxy S23         2023  40000
# 4  Samsung Galaxy S22         2022  26000
