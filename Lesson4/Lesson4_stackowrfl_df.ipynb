# %%
import pandas as pd

df = pd.read_csv('C:/Users/Adm/Desktop/GoIT/stack-overflow-developer-survey-2023/survey_results_public.csv')

# %%
online_course_learners = df[df['LearnCode'].str.contains('Online', case=False, na=False)]

num_online_course_learners = online_course_learners['ResponseId'].nunique()

print(f"Кількість респондентів, які навчалися програмувати за допомогою онлайн курсів: {num_online_course_learners}")
# Out:
# Кількість респондентів, які навчалися програмувати за допомогою онлайн курсів: 77027

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
python_strong_filter = df.loc[df['LanguageHaveWorkedWith'] == 'Python']
display(python_strong_filter)
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 113           114  I agree                     I am a developer by profession
# 220           221  I agree  I am not primarily a developer, but I write co...
# 287           288  I agree                        I code primarily as a hobby
# 307           308  I agree                              I am learning to code
# 336           337  I agree                              I am learning to code
# ...           ...      ...                                                ...
# 88767       88768  I agree                     I am a developer by profession
# 88801       88802  I agree                        I code primarily as a hobby
# 88876       88877  I agree                              I am learning to code
# 89001       89002  I agree                        I code primarily as a hobby
# 89145       89146  I agree  I am not primarily a developer, but I write co...
#
# ...

# %%
print(df['LanguageHaveWorkedWith'])
df[df['LanguageHaveWorkedWith'].str.contains('Python', na=False)]
# Out:
# 0                                                      NaN
# 1                               HTML/CSS;JavaScript;Python
# 2                               Bash/Shell (all shells);Go
# 3        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 4                           HTML/CSS;JavaScript;TypeScript
#                                ...
# 89179              HTML/CSS;Java;JavaScript;SQL;TypeScript
# 89180                                 Dart;Java;Python;SQL
# 89181    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89182    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 89183                      C#;Go;JavaScript;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 89184, dtype: object
#        ResponseId     Q120                      MainBranch  \
# 1               2  I agree  I am a developer by profession
# 7               8  I agree  I am a developer by profession
# 9              10  I agree  I am a developer by profession
# ...

# %%
work_exp = df.loc[:, 'YearsCode']
print(work_exp)
print()
work_exp = pd.to_numeric(work_exp, errors='coerce').fillna(0)
print(work_exp)
work_exp.mean()
# Out:
# 0        NaN
# 1         18
# 2         27
# 3         12
# 4          6
#         ...
# 89179     20
# 89180      5
# 89181     10
# 89182      3
# 89183     17
# Name: YearsCode, Length: 89184, dtype: object
#
# 0         0.0
# 1        18.0
# 2        27.0
# 3        12.0
# 4         6.0
#          ...
# 89179    20.0
# 89180     5.0
# 89181    10.0
# 89182     3.0
# 89183    17.0
# Name: YearsCode, Length: 89184, dtype: float64
# 13.491085844994618

# %%
remote_group = df.groupby('RemoteWork')
print(remote_group.size())
print()
print(type(remote_group.size()))
print()
print(remote_group.size().loc['Remote'])
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    31131
# In-person                               12113
# Remote                                  30566
# dtype: int64
#
# <class 'pandas.core.series.Series'>
#
# 30566
